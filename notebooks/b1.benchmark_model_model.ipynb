# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read data

# %%
df_clean = pd.read_csv("../data/data_preprocessed_v0.csv",index_col=0)
df_clean.head()
# Out:
#            grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G
# member_id
# 1314167      False    False     True    False    False    False    False  \
# 1306957      False    False    False    False    False     True    False
# 1306721      False     True    False    False    False    False    False
# 1298717      False    False     True    False    False    False    False
# 1303503      False     True    False    False    False    False    False
#
#            home_ownership:MORTGAGE  home_ownership:NONE  home_ownership:OTHER
# member_id
# 1314167                      False                False                 False  \
# 1306957                      False                False                 False
# 1306721                      False                False                 False
# 1298717                      False                False                 False
# 1303503                      False                False                 False
#
# ...
